# %% [markdown]
# ## Midterm Exam Data

# %%
users=read.csv(file="data.csv", header=TRUE, sep=",")

#general grading notes. Take max of 2 off for:
#-1 = rather than <- 
users
# Out:
#      id        username gender sales repeat. tenure
# 1     1    James Cutney   male   200    TRUE    3.2
# 2     2      John Smith   male  <NA>   FALSE    4.3
# 3     3 Susan Sanderson female   200   FALSE    1.3
# 4     4      Bree Landy female  <NA>   FALSE    0.1
# 5     5     Kelly Smith female   404   FALSE      2
# 6     6    James Cutney   male   200    TRUE    3.2
# 7     7      John Smith   male  <NA>   FALSE    4.3
# 8     8 Susan Sanderson female   200   FALSE    1.3
# 9     9      Bree Landy female  <NA>   FALSE    0.1
# 10   10     Kelly Smith female   404   FALSE      2
# 11   11    James Cutney   male   200    TRUE    3.2
# 12   12      John Smith   male  <NA>   FALSE    4.3
# 13   13 Susan Sanderson female   200   FALSE    1.3
# 14   14      Bree Landy female  <NA>   FALSE    0.1
# 15   15     Kelly Smith female   404   FALSE      2
# 16   16    James Cutney   male   200    TRUE    3.2
# 17   17      John Smith   male  <NA>   FALSE    4.3
# ...
